# %%
import pandas as pd
import numpy as np
import seaborn as sns
from util import get_paths, create_coverage_stratas

# %%
paths_df = get_paths('./tgs/train', 'masks', 'images')

# %%
paths_df.head(10)
# Out:
#            id                              mask  \
# 0  000e218f21  ./tgs/train/masks/000e218f21.png
# 1  003c477d7c  ./tgs/train/masks/003c477d7c.png
# 2  00441f1cf2  ./tgs/train/masks/00441f1cf2.png
# 3  0050766ae2  ./tgs/train/masks/0050766ae2.png
# 4  005b452274  ./tgs/train/masks/005b452274.png
# 5  0061281eea  ./tgs/train/masks/0061281eea.png
# 6  008a50a2ec  ./tgs/train/masks/008a50a2ec.png
# 7  00950d1627  ./tgs/train/masks/00950d1627.png
# 8  00a3af90ab  ./tgs/train/masks/00a3af90ab.png
# 9  00cda0328c  ./tgs/train/masks/00cda0328c.png
#
#                                  img
# 0  ./tgs/train/images/000e218f21.png
# 1  ./tgs/train/images/003c477d7c.png
# 2  ./tgs/train/images/00441f1cf2.png
# 3  ./tgs/train/images/0050766ae2.png
# 4  ./tgs/train/images/005b452274.png
# 5  ./tgs/train/images/0061281eea.png
# 6  ./tgs/train/images/008a50a2ec.png
# 7  ./tgs/train/images/00950d1627.png
# 8  ./tgs/train/images/00a3af90ab.png
# 9  ./tgs/train/images/00cda0328c.png

# %%
coverage_df = create_coverage_stratas(paths_df)

# %%
coverage_df.head(10)
# Out:
#            id                              mask  \
# 0  000e218f21  ./tgs/train/masks/000e218f21.png
# 1  003c477d7c  ./tgs/train/masks/003c477d7c.png
# 2  00441f1cf2  ./tgs/train/masks/00441f1cf2.png
# 3  0050766ae2  ./tgs/train/masks/0050766ae2.png
# 4  005b452274  ./tgs/train/masks/005b452274.png
# 5  0061281eea  ./tgs/train/masks/0061281eea.png
# 6  008a50a2ec  ./tgs/train/masks/008a50a2ec.png
# 7  00950d1627  ./tgs/train/masks/00950d1627.png
# 8  00a3af90ab  ./tgs/train/masks/00a3af90ab.png
# 9  00cda0328c  ./tgs/train/masks/00cda0328c.png
#
#                                  img  coverage  coverage_strata
# 0  ./tgs/train/images/000e218f21.png  0.000000                0
# 1  ./tgs/train/images/003c477d7c.png  0.032938                0
# 2  ./tgs/train/images/00441f1cf2.png  0.000000                0
# 3  ./tgs/train/images/0050766ae2.png  0.000000                0
# 4  ./tgs/train/images/005b452274.png  0.000000                0
# ...

# %%
coverage_df.to_csv('stratas_data.csv')
